# %% [markdown]
# ### IDs:
# Insert yours IDs to the cell below

# %% [markdown]
# ID #1: 034537969
#
# ID #2: 322156159
#
# Ido Hadanny, Ilia Kohanovski

# %% [markdown]
# ## Read the following instructions carefully:
#
# 1. This jupyter notebook contains all the step by step instructions needed for this exercise.
# 1. You are free to add cells.
# 1. Write your functions and your answers in this jupyter notebook only.
# 1. Answers to theoretical questions should be written in **markdown cells (with $\LaTeX$ support)**.
# 1. Submit this jupyter notebook only using your ID as a filename. Not to use ZIP or RAR. For example, your Moodle submission file name should look like this (two id numbers): `123456789_987654321.ipynb`.

# %% [markdown]
# ### Question 1 - Correlations (15 points)

# %% [markdown]
# Provide example datapoints matching the following descriptions. Each example should be constructed over n=50 datapoints. Provide a table description of the example data as well as a scatter plot. If you think that the situation described is impossible then clearly explain why (you don’t need to give a rigorous proof).<br>
# Pearson(x,y) = Pearson correlation<br>
# τ(x,y) = Kendall rank correlation<br>
# ρ(x,y) = Spearman rank correlation <br>

# %% [markdown]
# #### 1.A
# Data in which the Pearson(x,y)>0.9 but where n-1 points can be selected so that for the vectors restricted to those we have Pearson correlation <0.1

# %%
import numpy as np
from scipy.stats import stats
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = [0]*49 + [1] + [10]
y = [0]*49 + [-1] + [10]
plt.scatter(x, y)
plt.show()
print("pearson x,y", stats.pearsonr(x, y)[0])
print("pearson x[:50], y[:50]", stats.pearsonr(x[:50], y[:50])[0])
# Out:
# pearson x,y 0.9802057069663801
# pearson x[:50], y[:50] -1.0

# %% [markdown]
# #### 1.B
# Data with τ(x,y) > ρ(x,y) + 0.4

# %%
N=1000
x = list(range(1,N))
y = list(range(int(N/2),0,-1))+list(range(N-1,int(N/2),-1))
p =stats.kendalltau(x, y).correlation
t =stats.spearmanr(x, y)[0]
diff = t-p
plt.scatter(x, y)
plt.show()
print("spearman:", t)
print("kendalltau:", p)
print('spearman - kendalltau:', diff)
# Out:
# spearman: 0.5
# kendalltau: 0.001001001001001001
# spearman - kendalltau: 0.498998998998999

# %% [markdown]
# #### 1.C
# Data with τ(x,y) < ρ(x,y) – 0.4

# %%
N=1000
x = list(range(1,N))
y = -np.array(list(range(int(N/2),0,-1))+list(range(N-1,int(N/2),-1)))
p =stats.kendalltau(x, y).correlation
t =stats.spearmanr(x, y)[0]
diff = t-p
plt.scatter(x, y)
plt.show()
print("spearman:", t)
print("kendalltau:", p)
print('spearman - kendalltau:', diff)
# Out:
# spearman: -0.5
# kendalltau: -0.001001001001001001
# spearman - kendalltau: -0.498998998998999

# %% [markdown]
# #### 1.D
# Data with Pearson(x,y) < ρ(x,y) – 0.6

# %%
x = np.array([-1] + list(range(0, 50)) + [100])
y = np.array([-1000] + list(range(0, 50)) + [100])
plt.scatter(x, y)
plt.show()

print("pearsonr", stats.pearsonr(x, y)[0])
print("spearman", stats.spearmanr(x, y).correlation)
# Out:
# pearsonr 0.3259615672732229
# spearman 0.9999999999999999

# %% [markdown]
# #### 1.E
# Data with Pearson(x,y) < ρ(x,y) – 1.2

# %%
x = np.array(list(range(0,50)) + [1000])
y = np.array(list(range(0,50)) + [-1000])
plt.scatter(x, y)
plt.show()

print("pearsonr", stats.pearsonr(x, y)[0])
print("spearman", stats.spearmanr(x, y).correlation)
# Out:
# pearsonr -0.9789570033514805
# spearman 0.8846153846153845

# %% [markdown]
# #### 1.F
# Data with τ(x,y) < ρ(x,y) – 1.2

# %% [markdown]
# Impossible! spearman and kendall can't be that different.
# It looks hard to prove, but we get the higher difference when x is [1,..,N] and y is [N/2..1,N,..N/2+1]
# And in this way we get maximum difference of 0.5

# %%
import itertools
N = 8
x = range(1, N)
print("best permutations for N =",N)        
for y in itertools.permutations(range(1, N)):
    diff = stats.kendalltau(x, y).correlation - stats.spearmanr(x, y)[0]
    if (abs(diff)>0.3):
        print(y,abs(diff))
# Out:
# best permutations for N = 8
# (3, 2, 1, 7, 6, 5, 4) 0.3571428571428571
# (4, 3, 2, 1, 7, 6, 5) 0.3571428571428571
# (4, 5, 6, 7, 1, 2, 3) 0.3571428571428571
# (5, 6, 7, 1, 2, 3, 4) 0.3571428571428571

# %% [markdown]
# ### Question 2 - Analysis of the Indian Liver Patient Dataset (50 points)

# %% [markdown]
# Perform data analysis on the Indian Liver Patient Dataset
# References:
# * Bendi Venkata Ramana, Prof. M. S. Prasad Babu and Prof. N. B. Venkateswarlu, A Critical Comparative Study of Liver Patients from USA and INDIA: An Exploratory Analysis, International Journal of Computer Science Issues, ISSN :1694-0784, May 2012.
# * Bendi Venkata Ramana, Prof. M. S. Prasad Babu and Prof. N. B. Venkateswarlu, A Critical Study of Selected Classification Algorithms for Liver Disease Diagnosis, International Journal of Database Management Systems (IJDMS), Vol.3, No.2, ISSN : 0975-5705, PP 101-114, May 2011.
#
# Use the following link to find the details of the data: https://archive.ics.uci.edu/ml/datasets/ILPD+(Indian+Liver+Patient+Dataset)
#
# In the follwong cells write a report for your analysis. In your report provide a clear description of the analysis methods and of the results. This should include a graphical representation of the results and the conclusions. Provide p-values or other indicators of the statistical significance where appropriate. <br>
# Design your report to be concise but still cover interesting findings.
#
# There are missing values in the data. Find them and impute them by using the median value of the relevant feature (column).
# Address the following questions:
# * Using confidence intervals determine features for which you can state with confidence of 95% that the healthy population mean is larger/smaller than the disease population mean.
# * Draw histograms for each numerical feature. Inspect the observed distributions and then use MLE to plot, on the same figures, fits of the distributions.
# * For each pair of numerical feature, calculate correlations and indicate whether you find them significant. For select pairs, with significant correlations, draw joint plot with marginal histograms (see Seaborn joint plot) and find bivariate normal fits. Then use the example code below to draw plots of the bivariate pdfs (you may edit the code as you see fit).
# * Are there pairs that are significantly correlated in males but not in females? The opposite? How about healthy vs disease? Can you graphically represent this?
# * For each numerical feature, except age, plot the distribution for this feature against bins of age. In each bin provide a split violin plot, with different colors for healthy and disease.
#
# Suggest, state and address at least one original question.

# %%
df = pd.read_csv(
    'ILPD.csv', names=['age', 'gender', 'tb', 'db', 'alkphos', 
                      'sgpt', 'sgot', 'tp', 'alb', 'ag', 'selector'],
    index_col=False
                )

# %% [markdown]
# find missing values:

# %%
print(len(df))
print(df.count()[df.count() < len(df)])
# Out:
# 583
# ag    579
# dtype: int64

# %% [markdown]
# impute with median:

# %%
df = df.fillna(df.median())

# %% [markdown]
# healthy and disease population sizes:

# %%
#1 is not healthy and 2 is healthy
df.groupby('selector').size()
# Out:
# selector
# 1    416
# 2    167
# dtype: int64

# %% [markdown]
# features for which you can state with confidence of 95% that the healthy population mean is larger/smaller than the disease population mean

# %%
from scipy.stats import norm,cauchy

gmean = df.groupby('selector').mean()
mean_diff = gmean.loc[1] - gmean.loc[2]
gvar = df.groupby('selector').var()
se = np.sqrt(gvar.loc[1]/416 + gvar.loc[2]/167)
z = mean_diff / se 
alpha = 1-0.95
print('z statistics that satisfies p value:')
z[(norm.cdf(z) < alpha/2) | (1-alpha/2 < norm.cdf(z))]
# Out:
# z statistics that satisfies p value:
# age        3.226762
# tb         8.421698
# db         9.410340
# alkphos    5.807575
# sgpt       6.215802
# sgot       5.781288
# alb       -3.948000
# ag        -4.186038
# dtype: float64

# %%
df.hist(figsize=(20,20),bins=40)
plt.show()

# %% [markdown]
# do log transformation for the features that look log-normal

# %%
log_normal = ['alkphos', 'db', 'sgot', 'sgpt', 'tb']
df[log_normal] = np.log(df[log_normal])

# %% [markdown]
# mle estimation and histogram
# We used Cauchy distribution for 'alb' (Cauchy is good for ratios)
# For others we used normal distribution and log_normal. Log_normal had not always good fit, so it can be exponential instead, or the log of the R.V. can be normal mixture. But, anyway all of it is heuristics, so we leaved it to be log_normal.

# %%
for col in set(df.columns) - set(['gender', 'selector']):
    feat = df[col]
    bins = 30
    feat.hist(bins=bins)
    x = np.linspace(feat.min(), feat.max(), bins)
    if col == 'alb':
        u, s = cauchy.fit(feat)
        ser = cauchy.cdf((x-u)/s)*feat.count()
    else:
        u = feat.mean()
        s = np.sqrt(((feat - u)**2).mean())
        ser = norm.cdf((x-u)/s)*feat.count()
    plt.plot(x[1:], ser[1:] - ser[:-1])
    plt.title(col)
    plt.show()

# %%
import seaborn as sns
corr = df.drop('selector', axis=1).corr()
def corr_heat_map(corr):
    ax = sns.heatmap(
        corr, 
        vmin=-1, vmax=1, center=0,
        cmap=sns.diverging_palette(20, 220, n=200),
        square=True
    )
    ax.set_xticklabels(
        ax.get_xticklabels(),
        rotation=45,
        horizontalalignment='right'
    );
corr_heat_map(corr)

# %% [markdown]
# For select pairs, with significant correlations, draw joint plot with marginal histograms (see Seaborn joint plot) and find bivariate normal fits

# %%
def flatten_corr(corr):
    sig_corr = corr.stack().reset_index()
    sig_corr.columns = ['feat_a', 'feat_b', 'my_corr']
    sig_corr = sig_corr.query('feat_a < feat_b').sort_values('my_corr')
    return sig_corr
def p_value(row):
    return stats.pearsonr(df[row['feat_a']],df[row['feat_b']])[1]

sig_corr = flatten_corr(corr[abs(corr) > 0.67]) #the threshold chosed by looking on the plots
sig_corr['p_value'] = sig_corr.apply(p_value,axis=1)
sig_corr[sig_corr['p_value']<0.05]
# Out:
#    feat_a feat_b   my_corr        p_value
# 15     ag    alb  0.686091   2.586581e-82
# 12    alb     tp  0.784053  1.934141e-122
# 8    sgot   sgpt  0.841705  1.217714e-157
# 3      db     tb  0.965640   0.000000e+00

# %%
# Example code for bivariate pdfs
from scipy.stats import multivariate_normal as mn
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_2d_Gaussian_pdf(means, cov, ax = None):
    n = 100
    x1 = np.linspace(means[0] - 3 * np.sqrt(cov[0][0]), means[0] + 3 * np.sqrt(cov[0][0]), n)
    x2 = np.linspace(means[1] - 3 * np.sqrt(cov[1][1]), means[1] + 3 * np.sqrt(cov[1][1]), n)
    x1_v, x2_v = np.meshgrid(x1, x2)
    Xgrid = np.vstack([x1_v.ravel(), x2_v.ravel()]).T
    Y = mn.pdf(Xgrid, means, cov)
    if ax is None:
        fig, ax = plt.subplots()
        ax.axis('equal')
        ax.grid(alpha=0.2)
    ax.pcolorfast(x1, x2, Y.reshape(x1_v.shape), alpha=0.5, cmap='Blues')
    ax.contour(x1_v, x2_v, Y.reshape(x1_v.shape),
               levels=[0.05, 0.1, 0.15, 0.2], alpha=0.3, colors='b')
    return ax

# %%
def plot_corr_and_bivariate_pdf(df, feat_a, feat_b, title):
    x, y = df[feat_a], df[feat_b]
    means = [x.mean(), y.mean()]
    cov = np.cov([x, y])
    g = sns.jointplot(x, y)
    plot_2d_Gaussian_pdf(means, cov, g.ax_joint)
    my_corr = df[[feat_a, feat_b]].corr().iloc[0, 1]
    g.fig.suptitle(f"{title} corr:{my_corr}")
for _, (feat_a, feat_b, _,_) in sig_corr.iterrows():
    plot_corr_and_bivariate_pdf(df, feat_a, feat_b, 'all samples')
    plt.show()

# %% [markdown]
# Are there pairs that are significantly correlated in males but not in females? The opposite? How about healthy vs disease?

# %%
def compare_sig_corrs_per_group(groupby):
    corrs = [(g, flatten_corr(gdf.corr())) for 
             g, gdf in df.groupby(groupby)]
    comp = pd.merge(corrs[0][1], corrs[1][1], on=['feat_a', 'feat_b'], how='outer',
            suffixes=[corrs[0][0], corrs[1][0]])
    return comp.query(
        f"(abs(my_corr{corrs[0][0]}) > 0.67 and abs(my_corr{corrs[1][0]}) < 0.67) or " 
        f"(abs(my_corr{corrs[0][0]}) < 0.67 and abs(my_corr{corrs[1][0]}) > 0.67)")
compare_sig_corrs_per_group('gender')
# Out:
#    feat_a feat_b  my_corrFemale  my_corrMale
# 41     ag    alb       0.775971      0.66612

# %%
for _, (feat_a, feat_b, _, _) in compare_sig_corrs_per_group('gender').iterrows():
    for g, gdf in df.groupby('gender'):
        plot_corr_and_bivariate_pdf(gdf, feat_a, feat_b, g)
        plt.show()

# %%
compare_sig_corrs_per_group('selector')
# Out:
#    feat_a feat_b  my_corr1  my_corr2
# 32     ag    alb  0.662268  0.725630
# 34   sgot   sgpt  0.850163  0.650438

# %%
for _, (feat_a, feat_b, _, _) in compare_sig_corrs_per_group('selector').iterrows():
    for g, gdf in df.groupby('selector'):
        plot_corr_and_bivariate_pdf(gdf, feat_a, feat_b, 
                                    'disease' if g == 1 else 'healthy' )
        plt.show()

# %% [markdown]
# For each numerical feature, except age, plot the distribution for this feature against bins of age. In each bin provide a split violin plot, with different colors for healthy and disease

# %%
df["age_group"] = df.age.apply(
    lambda x: 20 if x < 40 else 40 if x < 60 else 60)
df["selector_group"] = df["selector"].apply(lambda x: 'disease' if x == 1 else 'healthy')
for col in set(df.columns) - set(['age_group', 'age', 'selector', 'selector_group', 'gender']):
    ax = sns.violinplot(x="age_group", y=col, hue='selector_group', data=df,
                   pallete='muted', split=True)
    plt.show()

# %% [markdown]
# Suggest, state and address at least one original question:
#
# from the violin plots, it looks like the ag ratio is dramatically declining in liver disease patients, while for healthy individuals it looks like it's even slightly rising as they age. can we use it as a marker of the disease progress? It looks like Dr. google agrees: https://www.webmd.com/a-to-z-guides/what-is-a-total-serum-protein-test#1
#
# (but on the other hand, Dr. google agrees with almost any conclusion to some degree :)

# %% [markdown]
# ### Question 3 - Log Normal (15 points)

# %% [markdown]
# Consider Y1 ~ LogNormal(0,0.25) (recall that μ and σ are the mean and std of the underlying normal distribution)  and Y2 ~ LogNormal(0,1).

# %% [markdown]
# #### 3.A
# Draw a plot of the pdfs for Y1 and Y2 on the same axes, over the x range of [0 10].

# %%
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
y1 = stats.lognorm(s=0.25)
y2 = stats.lognorm(s=1)

x = np.linspace(0, 10, 10000)
y1vals = [y1.pdf(x) for x in x]
y2vals = [y2.pdf(x) for x in x]

plt.xlim(0,10)
plt.plot(x,y1vals)
plt.xlim(0,10)
plt.plot(x,y2vals);

# %% [markdown]
# #### 3.B
# What is E(Y1)? E(Y2)?

# %%
print('E(Y1):',y1.mean())
print('E(Y2):',y2.mean()) #e^0.5
# Out:
# E(Y1): 1.0317434074991025
# E(Y2): 1.6487212707001282

# %% [markdown]
# #### 3.C
# What is the probability of Y1 being more than 4 stds larger than its mean?

# %%
1-y1.cdf(4*y1.mean())
#equals to 1-stats.norm(0,0.25).cdf(np.log(4*y1.mean()))
# Out:
# 7.1324848249787465e-09

# %% [markdown]
# #### 3.D
# What is the probability of Y2 being more than 4 stds larger than its mean?

# %%
1-y2.cdf(4*y2.mean())
# Out:
# 0.029627649366657294

# %% [markdown]
# #### 3.E
# What is the IQR of Y1? Of Y2?

# %%
print('Y1 iqr:',y1.ppf(0.75)-y1.ppf(0.25))
print('Y2 iqr:',y2.ppf(0.75)-y2.ppf(0.25))
# Out:
# Y1 iqr: 0.3388453255727636
# Y2 iqr: 1.4536148002949796

# %% [markdown]
# ### Question 4 - CLT for Markov chains (20 points)

# %% [markdown]
# In this exercise you will construct trajectories of Markovian dice rolling results in the following way.<br>
# The first roll, X0, is Unif(1..6)<br>
# After i rolls are determined the i+1st, Xi+1, is drawn according to the row that corresponds to the value of Xi in the matrix T below. <br>
# In other words, T is the transition matrix of a Markov chain and the initial distribution is uniform.
#
# \begin{equation*}
# T =
# \begin{pmatrix}
# 0.5 & 0.2 & 0.05 & 0 & 0.05 & 0.2 \\
# 0.2 & 0.5 & 0.2 & 0.05 & 0 & 0.05 \\
# 0.05 & 0.2 & 0.5 & 0.2 & 0.05 & 0 \\
# 0 & 0.05 & 0.2 & 0.5 & 0.2 & 0.05 \\
# 0.05 & 0 & 0.05 & 0.2 & 0.5 & 0.2 \\
# 0.2 & 0.05 & 0 & 0.05 & 0.2 & 0.5
# \end{pmatrix}
# \end{equation*}

# %% [markdown]
# #### 4.A
# Construct 1000 trajectories, each of length 20.
# 1. What do you expect the average value of all 20 numbers in a trajectory to be?
# 2. Compute the average value of each such trajectory. Draw a histogram of the 1000 numbers you received, using 100 bins.
# 3. What does the distribution look like? What are the empirical mean and the std?

# %% [markdown]
# 1) The expected value is 3.5 ( (6+1)/2 ). p=[1/6,1/6,1/6,1/6,1/6,1/6] is initial propability distribution. p*T=p => therefore for each step the probability to get any number is equal.

# %%
import numpy as np
import seaborn as sns

def get_trajs(traj_len):
    T = np.ndarray(shape=(6,6))
    for i in range(6):
        T[i]= np.roll([0.5,0.2,0.05,0,0.05,0.2],i)

    currStates = np.random.choice(6,1000)
    trajs = np.ndarray(shape=(traj_len,1000))
    for i in range(traj_len):
        trajs[i]=currStates
        f = lambda row: np.random.choice(6,p=row)
        currStates = np.apply_along_axis(f,1,T[currStates])
    trajs+=1
    return trajs.transpose()

# %%
trajs=get_trajs(20)
firstmeans = trajs.mean(axis=1)
pd.Series(firstmeans).hist(bins=100);

# %% [markdown]
# Looks like normal distribution, but very roughly

# %%
print('mean:',np.mean(firstmeans))
# Out:
# mean: 3.4935

# %%
print('std:',np.std(firstmeans))
# Out:
# std: 0.7164270723527971

# %% [markdown]
# #### 4.B
# Construct 1000 trajectories, each of length 2000.
# 1. What do you expect the average value of all 2000 numbers in a trajectory to be?
# 2. Compute the average value of each such trajectory. Draw a histogram of the 1000 numbers you received, using 100 bins.
# 3. What does the distribution look like? What are the empirical mean and the std?

# %% [markdown]
# 1) Same. See the explanation for the previous question

# %%
trajs = get_trajs(1000)
secondmeans = trajs.mean(axis=1)
pd.Series(secondmeans).hist(bins=100);

# %% [markdown]
# looks like normal distribution

# %%
print('mean:',np.mean(secondmeans))

# %%
print('std:',np.std(secondmeans))

# %% [markdown]
# #### 4.C
# Draw normal fit curves on your two histograms.

# %%
def norm_fit(means):
    means = pd.Series(means)
    pd.Series(means).hist(bins=100);
    feat = means
    x = np.linspace(feat.min(), feat.max(), 100)
    ser = norm.cdf((x-feat.mean())/feat.std())*feat.count()
    plt.plot(x[1:], ser[1:] - ser[:-1])
    plt.show()
norm_fit(firstmeans)
norm_fit(secondmeans)

# %% [markdown]
# #### 4.D - Bonus
# Can you try to formulate a CLT for Markov chains from your findings?

# %% [markdown]
# We got by example (without proof) that when the initial distribution of the Markov Chain states is the stationary distribution, then for n random variables of the Markov Chain X1,..,Xn, as n gets larger the distribution of the average of X1..Xn (i.e. $\sum(X_i)/n$ ) approximates to Normal distribution.
